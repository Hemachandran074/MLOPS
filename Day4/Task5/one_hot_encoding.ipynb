# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
d = pd.read_csv('carprices.csv')

# %%
dummies = pd.get_dummies(d['Car Model'])

# %%
merged = pd.concat([d, dummies], axis='columns')

# %%
final = merged.drop(['Car Model', 'Mercedez Benz C class'], axis='columns')

# %%
x = final.drop('Sell Price($)', axis='columns')

# %%
y = final['Sell Price($)']

# %%
model = LinearRegression()

# %%
model.fit(x, y)
model.score(x, y)
# Out:
# 0.9417050937281082

# %%
model.predict([[45000, 15000, 0, 0,]])
# Out:
# c:\chandru\Python Files\MLOPS\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-19944483.28246081])

# %%
model.predict([[83000, 9, 0, 1,]])
# Out:
# c:\chandru\Python Files\MLOPS\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([9526.20216013])
